# %% [markdown]
# <a href="https://colab.research.google.com/github/emerson-matos/tcc-notebooks/blob/main/reviews/analise_exploratoria_2018%2Bfiltrado%2Btimechart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Configurando ambiente

# %% [markdown]
# monta o google drive e define paleta de cores para o seaborn utilizar

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import ScalarFormatter

from google.colab import drive
sns.color_palette("tab10")
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# autentica o usuario no google para poder utilizar o google sheets

# %%
from google.colab import auth
import gspread
from google.auth import default

auth.authenticate_user()

creds, _ = default()

gc = gspread.authorize(creds)

# %% [markdown]
# faz o download de stopwords e punkt do nltk

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Baixe a lista de stopwords em português
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# # Dados dos hoteis

# %% [markdown]
# definindo a data dos arquivos que serão utilizados

# %%
date = "2023/07/07"

# %% [markdown]
# ## Cria o DataFrame

# %% [markdown]
# carregamos então o google sheets onde está definida a lista de hotéis em um dataframe pandas e validamos a existencia do sns

# %%
ws = gc.open('PGC-hotels')
emerson = ws.worksheet('Emerson')
hotels = pd.DataFrame(emerson.get_all_records())[['name', 'stars', 'overall_rating', 'region', 'state', 'qtd_reviews', 'source']]

sns.__version__
# Out:
# '0.12.2'

# %% [markdown]
# ### carregando um unico arquivo

# %%
filename = 'grand-oca-maragogi-gm-reviews.csv'
dados = pd.read_csv(f"/content/gdrive/MyDrive/tcc/data/{date}/{filename}")
dados['source'] = filename.split('.')[0]
dados.loc[1]['text']
# Out:
# 'De tudo do Resort um serviço superou as minhas expectativas: a Yasmin é uma manicure sensacional, fez muitíssimo bem meu pé e minha mão, nota mil'

# %% [markdown]
# ### carregando todos os arquivos da pasta do google drive

# %%
import glob
import os

path_to_lookup = f'/content/gdrive/MyDrive/tcc/data/{date}/'
file_pattern = "*.csv"

# setting the path for joining multiple files
files = os.path.join(path_to_lookup, file_pattern)

# list of merged files returned
files = glob.glob(files)

dados = pd.concat(map(lambda file: pd.read_csv(file).assign(source=file.split("/")[-1].split('-gm-reviews')[0]), files), ignore_index=True)

# %%
df = dados[['retrieval_date', 'rating', 'relative_date', 'likes', 'user_is_local_guide', 'text', 'source', 'user_reviews']].copy()

# %% [markdown]
# ### Tratando dataset

# %% [markdown]
# #### preparando colunas

# %% [markdown]
# Transformamos a data relativa da realização do review em datetime e criamos novas colunas com partes dessa data e também quantidade de reviews de um usuario em um valor inteiro.

# %% [markdown]
# ##### definindo transformações

# %%
from datetime import datetime, timedelta
import re

def transform_user_reviews(x):
  if isinstance(x, str) and x == 'Um':
    1
  elif isinstance(x, str):
    return int(x.replace('.',''))
  return x

def from_relative_date_to_timestamp(row):
  # String de data relativa
  data_relativa_str = row.relative_date
  timestamp = row.retrieval_date

  # Converte a string em um objeto timedelta
  unidade_tempo = data_relativa_str.split()[1]
  quantidade_tempo = 1 if 'um' in data_relativa_str.split()[0] else int(data_relativa_str.split()[0])

  if 'segundo' in unidade_tempo:
      data_relativa = timedelta(seconds=quantidade_tempo)
  elif 'minuto' in unidade_tempo:
      data_relativa = timedelta(minutes=quantidade_tempo)
  elif 'hora' in unidade_tempo:
      data_relativa = timedelta(hours=quantidade_tempo)
  elif 'dia' in unidade_tempo:
      data_relativa = timedelta(days=quantidade_tempo)
  elif 'semana' in unidade_tempo:
      data_relativa = timedelta(weeks=quantidade_tempo)
  elif re.match(r"m(ê|e)s", unidade_tempo):
      data_relativa = timedelta(days=30*quantidade_tempo)
  elif 'ano' in unidade_tempo:
      data_relativa = timedelta(days=365*quantidade_tempo)
  else:
      return timestamp

  # Timestamp parse
  try:
    dt_timestamp = datetime.strptime(timestamp, '%Y-%m-%d %H:%M:%S.%f')
  except:
    dt_timestamp = datetime.strptime(timestamp, '%Y-%m-%d %H:%M:%S')

  return (dt_timestamp - data_relativa).date()

# %% [markdown]
# ##### transformações rápidas

# %%
df['user_reviews'] = df['user_reviews'].apply(transform_user_reviews).fillna(0) ## número de reviews do autor do review atual

df['data_avaliacao'] = pd.to_datetime(df.apply(from_relative_date_to_timestamp, axis=1)) ## data da avaliação

# Extract month and year from the 'date' column
df['mes_avaliacao'] = df['data_avaliacao'].dt.month
df['ano_avaliacao'] = df['data_avaliacao'].dt.year

# Create a new column representing the combination of month and year
df['mes_ano_avaliacao'] = df['data_avaliacao'].dt.to_period('M')

# %% [markdown]
# ##### contagem de avaliações por ano sem filtros

# %%
df.ano_avaliacao.value_counts()[df.ano_avaliacao.unique()]
# Out:
# 2023    11925
# 2022    16364
# 2021     8104
# 2020    12489
# 2019    18963
# 2018    12625
# 2017     4426
# 2016      940
# 2015      247
# 2014      106
# 2013       88
# 2012        9
# 2011        5
# Name: ano_avaliacao, dtype: int64

# %% [markdown]
# ##### Marcação de avaliações
#
# Marcando avaliações que:
#
# *   Possuem algum caractere
# *   Possuem três ou mais caracteres
# *   Foram realizados depois de 2017
# *   Foram traduzidos pelo google

# %%
df['com_texto'] = df['text'].str.len() > 2
df['nao_vazio'] = df['text'].notna()
df['traduzido'] = df['text'].str.contains('Tradução do Google', na=False)
df['depois_2017'] = df['ano_avaliacao'] > 2017

# %% [markdown]
# ##### marcando avaliações que serão analisados
#
# Então marcamos as avaliações de interesse, isto é as que iremos utilizar na analise, considerando os seguintes filtros:
# *   Reviews que foram públicados após 2017
# *   Não foram traduzidos pelo google
# *   E possuem mais de 2 caracteres no seu conteudo
#
#
# É esperado que a avaliação possua algum texto para que possa ser possivel detectar o seu sentimento por esse motivo escolhemos as que possuem mais de 2 caracteres em sua composição. Estamos também interessados em avaliações realizadas no idioma português e por este motivo filtramos também as que foram traduzidas pelo google.

# %%
df['analisar'] = (df['com_texto']) & (~df['traduzido']) & (df['depois_2017'])
analisar_df = df[df['analisar']].copy()

# %% [markdown]
# distribuição por ano da quantidade de avaliações que atendem o filtro utilizado

# %%
analisar_df.ano_avaliacao.value_counts()[analisar_df.ano_avaliacao.unique()]
# Out:
# 2023     9444
# 2022    11866
# 2021     5350
# 2020     6236
# 2019     9645
# 2018     6678
# Name: ano_avaliacao, dtype: int64

# %% [markdown]
# Tendo a lista de hotéis e a lista de avaliações, mesclamos ambas para poder gerar informações e poder realizar analises temporais de cada hotel e região de forma independente

# %%
import unicodedata

hotels['source_normalized'] = hotels['source'].apply(lambda x: unicodedata.normalize('NFKD', x).encode('ASCII', 'ignore').decode('utf-8'))
df['source_normalized'] = df['source'].apply(lambda x: unicodedata.normalize('NFKD', x).encode('ASCII', 'ignore').decode('utf-8'))

hotels_metadados = pd.merge(hotels, df, on="source_normalized")[['name', 'stars', 'overall_rating', 'region', 'state', 'analisar']]

# %%
hotels_reviews = hotels_metadados.groupby(['name', 'state', 'stars', 'overall_rating', 'analisar']).agg(counts=('analisar', 'size'))
hotels_reviews['total_counts'] = hotels_reviews.groupby('name')['counts'].transform('sum')

hotels_reviews['percentage'] = hotels_reviews['counts'] / hotels_reviews['total_counts'] * 100

# %% [markdown]
# #### quantidade de avaliações

# %% [markdown]
# ##### quantidade total de avaliações

# %%
df.shape[0] ## avaliações no total com e sem texto
# Out:
# 86291

# %% [markdown]
# ##### quantidade de avaliações que serão analisados

# %%
analisar_count = sum(df['analisar'])
analisar_perc = analisar_count / df.shape[0]

# %% [markdown]
# ##### quantidade de reviews traduzidos ou com menos de 3 caracteres (2 ou menos)

# %%
n_analisar_count = sum(~df['analisar'])
n_analisar_perc = n_analisar_count / df.shape[0]

# %% [markdown]
# ##### quantidade de reviews traduzidos e sem texto

# %%
traduzido_count = sum(df['traduzido'])
traduzido_perc = traduzido_count / df.shape[0] ## reviews traduzidos

# %%
com_texto_count = sum(df['com_texto'])
com_texto_perc = com_texto_count / df.shape[0] ## reviews traduzidos

# %%
depois_2017_count = sum(df['depois_2017'])
depois_2017_perc = depois_2017_count / df.shape[0] ## reviews traduzidos
antes_2017_count = sum(~df['depois_2017'])
antes_2017_perc = antes_2017_count / df.shape[0] ## reviews traduzidos

# %%
vazio_count = sum(~df['nao_vazio'])
vazio_perc = vazio_count / df.shape[0] ## reviews traduzidos
menos_2_carc_count = df.shape[0] - vazio_count - com_texto_count
menos_2_carc_perc = menos_2_carc_count / df.shape[0] ## reviews traduzidos

# %% [markdown]
# valores:

# %%
print(f'''Considerando todas as avaliações obtidas, temos:
\t1. {depois_2017_count}({depois_2017_perc:.2%}) enviadas depois de 2017 e {antes_2017_count}({antes_2017_perc:.2%}) enviadas em 2017 ou antes
\t2. {com_texto_count}({com_texto_perc:.2%}) com texto e 3 ou mais caracteres, {vazio_count}({vazio_perc:.2%}) sem texto e {menos_2_carc_count}({menos_2_carc_perc:.2%}) avaliações com 1 ou 2 caracteres
\t3. {traduzido_count}({traduzido_perc:.2%}) avaliações traduzidas'''
)
# Out:
# Considerando todas as avaliações obtidas, temos:
# 	1. 80470(93.25%) enviadas depois de 2017 e 5821(6.75%) enviadas em 2017 ou antes
# 	2. 56893(65.93%) com texto e 3 ou mais caracteres, 29386(34.05%) sem texto e 12(0.01%) avaliações com 1 ou 2 caracteres
# 	3. 4184(4.85%) avaliações traduzidas

# %%
print(f'E dentre todas as avaliações obtidas utilizaremos para a analise o total de {analisar_count}({analisar_perc:.2%}) e {n_analisar_count}({n_analisar_perc:.2%}) foram ignoradas')
# Out:
# E dentre todas as avaliações obtidas utilizaremos para a analise o total de 49219(57.04%) e 37072(42.96%) foram ignoradas

# %% [markdown]
# #### salvando dataset

# %%
from datetime import date
name = str(date.today())
analisar_df.to_csv(f'/content/gdrive/MyDrive/tcc/exploratoria/{name}-analisar.csv', index=False)
df.to_csv(f'/content/gdrive/MyDrive/tcc/exploratoria/{name}-df.csv', index=False)
hotels_reviews.reset_index().to_csv(f'/content/gdrive/MyDrive/tcc/exploratoria/{name}-hotels.csv', index=False)

# %% [markdown]
# #### *exemplo*

# %%
df.head()
# Out:
#                retrieval_date  rating   relative_date  likes  \
# 0  2023-07-07 00:33:49.026816     5.0   7 horas atrás     -1
# 1  2023-07-07 00:33:49.066269     5.0  10 horas atrás     -1
# 2  2023-07-07 00:33:49.096786     5.0  10 horas atrás      0
# 3  2023-07-07 00:33:49.126736     5.0  10 horas atrás      0
# 4  2023-07-07 00:33:49.155893     5.0  10 horas atrás     -1
#
#   user_is_local_guide                                               text  \
# 0                True                                                NaN
# 1               False                                                NaN
# 2               False                 Lugar fantástico, recomendo super.
# 3               False  (Tradução do Google) Ele disse (Original) Exel...
# 4                 NaN                                                NaN
#
#                       source user_reviews data_avaliacao  mes_avaliacao  \
# 0  hotel-marsol-beach-resort           17     2023-07-06              7
# 1  hotel-marsol-beach-resort           Um     2023-07-06              7
# 2  hotel-marsol-beach-resort            9     2023-07-06              7
# 3  hotel-marsol-beach-resort            2     2023-07-06              7
# 4  hotel-marsol-beach-resort            0     2023-07-06              7
#
#    ano_avaliacao mes_ano_avaliacao  com_texto  nao_vazio  traduzido  \
# 0           2023           2023-07      False      False      False
# 1           2023           2023-07      False      False      False
# 2           2023           2023-07       True       True      False
# 3           2023           2023-07       True       True       True
# 4           2023           2023-07      False      False      False
#
#    depois_2017  analisar          source_normalized
# 0         True     False  hotel-marsol-beach-resort
# 1         True     False  hotel-marsol-beach-resort
# 2         True      True  hotel-marsol-beach-resort
# 3         True     False  hotel-marsol-beach-resort
# 4         True     False  hotel-marsol-beach-resort

# %%
analisar_df.head()
# Out:
#                 retrieval_date  rating   relative_date  likes  \
# 2   2023-07-07 00:33:49.096786     5.0  10 horas atrás      0
# 5   2023-07-07 00:33:49.185915     5.0  10 horas atrás      0
# 16  2023-07-07 00:33:50.064473     5.0  11 horas atrás      0
# 17  2023-07-07 00:33:50.080896     5.0  11 horas atrás      0
# 19  2023-07-07 00:33:50.109826     5.0  11 horas atrás      0
#
#    user_is_local_guide                                text  \
# 2                False  Lugar fantástico, recomendo super.
# 5                 True                       Tudo perfeito
# 16                True                          excelente!
# 17                True                         Belo lugar.
# 19               False                         Ótimo local
#
#                        source user_reviews data_avaliacao  mes_avaliacao  \
# 2   hotel-marsol-beach-resort            9     2023-07-06              7
# 5   hotel-marsol-beach-resort           36     2023-07-06              7
# 16  hotel-marsol-beach-resort           52     2023-07-06              7
# 17  hotel-marsol-beach-resort           41     2023-07-06              7
# 19  hotel-marsol-beach-resort            7     2023-07-06              7
#
#     ano_avaliacao mes_ano_avaliacao  com_texto  nao_vazio  traduzido  \
# 2            2023           2023-07       True       True      False
# 5            2023           2023-07       True       True      False
# 16           2023           2023-07       True       True      False
# 17           2023           2023-07       True       True      False
# 19           2023           2023-07       True       True      False
#
#     depois_2017  analisar
# 2          True      True
# 5          True      True
# 16         True      True
# 17         True      True
# 19         True      True

# %%
hotels_reviews
# Out:
#                                                                                   counts  \
# name                                         state stars overall_rating analisar
# Cana Brava All Inclusive Resort              BA    4     4.6            False       3028
#                                                                         True        8119
# Grand Oca Maragogi                           AL    5     4.3            False       2427
#                                                                         True        2210
# Hotel Marsol Beach Resort                    RN    4     4.2            False       1470
#                                                                         True        1863
# Hotel Vila Galé - Touros                     RN    5     4.6            False       1433
#                                                                         True        4369
# Hotel Vila Galé Marés                        BA    5     4.5            False       3550
#                                                                         True        5033
# Hotel Vila Galé: Eco Resort - Cabo           PE    5     4.5            False       2645
#                                                                         True        2746
# Iberostar Bahia                              BA    5     4.7            False       7830
#                                                                         True        8383
# La Torre Resort All Inclusive                BA    4     4.7            False       3164
#                                                                         True        3060
# Makai Resort Aracaju - All Inclusive         SE    4     4.3            False       2448
#                                                                         True        2846
# Nauticomar Resort All Inclusive & Beach Club BA    4     4.3            False       2104
#                                                                         True        2187
# Salinas Maceió All Inclusive Resort          AL    4     4.7            False       2140
#                                                                         True        2541
# Salinas Maragogi All Inclusive Resort        AL    5     4.8            False       3539
#                                                                         True        3917
# Transamerica Comandatuba                     BA    4     4.8            False       1294
#                                                                         True        1945
#
#                                                                                   total_counts  \
# name                                         state stars overall_rating analisar
# Cana Brava All Inclusive Resort              BA    4     4.6            False            11147
#                                                                         True             11147
# Grand Oca Maragogi                           AL    5     4.3            False             4637
#                                                                         True              4637
# Hotel Marsol Beach Resort                    RN    4     4.2            False             3333
#                                                                         True              3333
# Hotel Vila Galé - Touros                     RN    5     4.6            False             5802
#                                                                         True              5802
# Hotel Vila Galé Marés                        BA    5     4.5            False             8583
#                                                                         True              8583
# Hotel Vila Galé: Eco Resort - Cabo           PE    5     4.5            False             5391
#                                                                         True              5391
# Iberostar Bahia                              BA    5     4.7            False            16213
#                                                                         True             16213
# La Torre Resort All Inclusive                BA    4     4.7            False             6224
#                                                                         True              6224
# Makai Resort Aracaju - All Inclusive         SE    4     4.3            False             5294
#                                                                         True              5294
# Nauticomar Resort All Inclusive & Beach Club BA    4     4.3            False             4291
#                                                                         True              4291
# Salinas Maceió All Inclusive Resort          AL    4     4.7            False             4681
#                                                                         True              4681
# Salinas Maragogi All Inclusive Resort        AL    5     4.8            False             7456
#                                                                         True              7456
# Transamerica Comandatuba                     BA    4     4.8            False             3239
#                                                                         True              3239
#
#                                                                                   percentage
# name                                         state stars overall_rating analisar
# Cana Brava All Inclusive Resort              BA    4     4.6            False      27.164259
#                                                                         True       72.835741
# Grand Oca Maragogi                           AL    5     4.3            False      52.339875
#                                                                         True       47.660125
# Hotel Marsol Beach Resort                    RN    4     4.2            False      44.104410
#                                                                         True       55.895590
# Hotel Vila Galé - Touros                     RN    5     4.6            False      24.698380
#                                                                         True       75.301620
# Hotel Vila Galé Marés                        BA    5     4.5            False      41.360830
#                                                                         True       58.639170
# Hotel Vila Galé: Eco Resort - Cabo           PE    5     4.5            False      49.063254
#                                                                         True       50.936746
# Iberostar Bahia                              BA    5     4.7            False      48.294578
#                                                                         True       51.705422
# La Torre Resort All Inclusive                BA    4     4.7            False      50.835476
#                                                                         True       49.164524
# Makai Resort Aracaju - All Inclusive         SE    4     4.3            False      46.241028
#                                                                         True       53.758972
# Nauticomar Resort All Inclusive & Beach Club BA    4     4.3            False      49.032859
#                                                                         True       50.967141
# Salinas Maceió All Inclusive Resort          AL    4     4.7            False      45.716727
#                                                                         True       54.283273
# Salinas Maragogi All Inclusive Resort        AL    5     4.8            False      47.465129
#                                                                         True       52.534871
# Transamerica Comandatuba                     BA    4     4.8            False      39.950602
#                                                                         True       60.049398

# %% [markdown]
# ### analise exploratoria

# %% [markdown]
# considerando todas as avaliações, então temos as seguintes metricas:

# %%
df.describe()
# Out:
#              rating         likes  mes_avaliacao  ano_avaliacao
# count  86291.000000  86291.000000   86291.000000   86291.000000
# mean       4.600630     -0.227880       6.849208    2020.147779
# std        0.864428      0.804257       1.333079       1.921575
# min        1.000000     -1.000000       1.000000    2011.000000
# 25%        5.000000     -1.000000       7.000000    2019.000000
# 50%        5.000000      0.000000       7.000000    2020.000000
# 75%        5.000000      0.000000       7.000000    2022.000000
# max        5.000000     25.000000      12.000000    2023.000000

# %% [markdown]
# agora agrupando por hoteis avaliados, considerando avaliações com algum caractere de texto(não vazias), com mais de 2 caracteres, traduzidas pelo google e registradas após 2017.

# %%
df.groupby('source').agg(nao_vazio=('nao_vazio', 'sum'),
                         com_texto=('com_texto', 'sum'),
                         traduzido=('traduzido', 'sum'),
                         depois_2017=('depois_2017', 'sum'))
# Out:
#                                               nao_vazio  com_texto  traduzido  \
# source
# cana-brava-all-inclusive-resort                    8583       8581        141
# grand-oca-maragogi                                 2948       2947        542
# hotel-marsol-beach-resort                          2150       2150        162
# hotel-vila-galé---touros                          4481       4480        111
# hotel-vila-galé-marés                            5723       5721        315
# hotel-vila-galé:-eco-resort---cabo                3219       3217        183
# iberostar-bahia                                   10587      10586       1464
# la-torre-resort-all-inclusive                      3847       3847        496
# makai-resort-aracaju---all-inclusive               3180       3180         84
# nauticomar-resort-all-inclusive-&-beach-club       2630       2628        228
# salinas-maceió-all-inclusive-resort               2836       2836        168
# salinas-maragogi-all-inclusive-resort              4572       4572        203
# transamerica-comandatuba                           2149       2148         87
#
#                                               depois_2017
# source
# cana-brava-all-inclusive-resort                     10656
# grand-oca-maragogi                                   4297
# hotel-marsol-beach-resort                            3128
# hotel-vila-galé---touros                            5802
# hotel-vila-galé-marés                              7981
# hotel-vila-galé:-eco-resort---cabo                  4934
# iberostar-bahia                                     14848
# la-torre-resort-all-inclusive                        5722
# makai-resort-aracaju---all-inclusive                 4917
# nauticomar-resort-all-inclusive-&-beach-club         3938
# salinas-maceió-all-inclusive-resort                 4497
# salinas-maragogi-all-inclusive-resort                6700
# transamerica-comandatuba                             3050

# %% [markdown]
# Agora a visualização sepando as avaliações que foram utilizadas na analise e as que não foram considerando informações de estrelas dos hotéis, quantidade de avaliações e classificação da avaliação concedida no momento do registro, temos:

# %%
valores = hotels_metadados.groupby(['state', 'analisar']).agg({'analisar': [ 'count' ],
                                                               'overall_rating': [ 'mean', 'min', 'max' ],
                                                               'stars': [ 'mean' ]})
valores
# Out:
#                analisar overall_rating               stars
#                   count           mean  min  max      mean
# state analisar
# AL    False        8106       4.623896  4.3  4.8  4.735998
#       True         8668       4.643205  4.3  4.8  4.706853
# BA    False       20970       4.617740  4.3  4.8  4.542680
#       True        28727       4.613016  4.3  4.8  4.467017
# PE    False        2645       4.500000  4.5  4.5  5.000000
#       True         2746       4.500000  4.5  4.5  5.000000
# RN    False        2903       4.397451  4.2  4.6  4.493627
#       True         6232       4.480424  4.2  4.6  4.701059
# SE    False        2448       4.300000  4.3  4.3  4.000000
#       True         2846       4.300000  4.3  4.3  4.000000

# %% [markdown]
# Similar ao conteúdo acima, porém mais visual

# %%
fig, axes = plt.subplots(1, 3, figsize=(25, 6))
state_counts = hotels_reviews.groupby(['state', 'analisar'])['counts'].sum().reset_index().sort_values('counts', ascending=False)

g = sns.barplot(data=state_counts, x='state', hue='analisar', y='counts', ax=axes[2])
axes[2].set_title('Count of reviews by State')
axes[2].set_xlabel('State')
axes[2].set_ylabel('')

sns.countplot(data=hotels_metadados, x='state', ax=axes[0])
axes[0].set_title('Hotel Count by State')
axes[0].set_xlabel('State')
axes[0].set_ylabel('Count')

sns.countplot(data=hotels_metadados, x='stars', hue='state', ax=axes[1])
axes[1].set_title('Hotel Count by Stars and State')
axes[1].set_xlabel('Stars')
axes[1].set_ylabel('')
axes[1].legend(title='State')

for ax in axes.flat:
    # Iterate over each bar in the subplot
    for p in ax.patches:
        # Get the count value of the bar
        count = p.get_height()
        # Add the count value as text annotation
        ax.annotate(f'{int(count)}', (p.get_x() + p.get_width() / 2, p.get_height()),
                          ha='center', va='bottom')

# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.2)

# Display the plots
plt.show()

# %% [markdown]
# Visualização da distribuição das notas atribuidas individualmente a cada avaliação.
# A grande maioria das avaliações 38347 (77,91%) foi realizada e atribuida a maior nota, 5, o que nos leva a acreditar que em grande parte a o sentimento geral é positivo.

# %%
sns.countplot(x="rating", data=analisar_df)
ax = plt.gca()
# Add count values on top of each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2, p.get_height()),
                       ha='center', va='bottom')
plt.show()

# %% [markdown]
# Agora estamos considerando apenas avaliações que serão utilizadas na analise, podemos observar a sua evolução em quantidade númerica durante o tempo, podendo notar uma quebra de tendência no crescimento pós 2019, nos anos de 2020 e 2021, provavelmente causado pelo confinamento decorrente da COVID-21 (referências?) e pós flexibilização do confinamento visualizamos um aumento no número de avaliações, levando em consideração que temos apenas 6 meses de avaliação em 2023 então possivelmente seguiremos com a tendencia de aumento de número de avaliações ano após ano.

# %%
f, _ = plt.subplots(figsize=(10, 5))

sns.despine(f)

g = sns.countplot(
    x="ano_avaliacao",
    hue="rating",
    data=analisar_df,
    edgecolor=".3",
    linewidth=.5,
)
ax = plt.gca()
# Add count values on top of each bar
for p in ax.patches:
  # Get the count value of the bar
  count = p.get_height()
  if (count > 2000):
    # Add the count value as text annotation
    ax.annotate(count,
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center',
                va='center',
                xytext=(0, 5), textcoords='offset points')

ax.yaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.autoscale()
plt.show()

# %% [markdown]
# Com o grafico abaixo podemos notar que a variação da nota atribuida tende a diminuir conforme o tempo passa, a quantidade de notas maiores é crescente, mas levando em consideração o grafico acima isso talvez seja causado pela crescete também da quantidade de avaliações com notas entre 4 e 5.

# %%
plt.figure(figsize=(10,5))
sns.relplot(x='ano_avaliacao', y='rating', kind="line", data=analisar_df)

# %% [markdown]
# Visualização individual da quantidade de avaliações realiadas anualmente para cada um deles, todos os gráficos possuem linhas referencia posicionadas em 300, 500 e 1000.
#
# <!-- # removidos -->
# <!-- # grand-palladium-imbassaí-resort-&-spa 18/19/20/21 -->
# <!-- # hotel-coroa-vermelha-beach-all-inclusive 18 / 19 / 20 -->
# <!-- # iberostar-selection-praia-do-forte 18 -->
# <!-- # sauípe-premium-brisa---all-inclusive 18/19/20 -->

# %%
# Create countplot with subplots
g = sns.catplot(
    x="ano_avaliacao",
    col="source",
    data=analisar_df,
    col_wrap=4,
    kind='count',
    height=4,
    aspect=1,
)

# Iterate over each subplot
for ax in g.axes.flat:
    # Iterate over each bar in the subplot
    for p in ax.patches:
        # Get the count value of the bar
        count = p.get_height()
        # Add the count value as text annotation
        ax.annotate(count,
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center',
                    va='center',
                    xytext=(0, 5), textcoords='offset points')
    ax.axhline(y=300, color='red', linestyle='-')
    ax.axhline(y=500, color='blue', linestyle='--')
    ax.axhline(y=1000, color='brown', linestyle=':')

# Set titles for each subplot
g.set_titles("Category: {col_name}")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# Visualização da nota individual dos hotéis com base nas avaliaçõesrealizadas durante o tempo.
#
# É fácil notar que a variação esta bastante concentrada na região acima de 4 para quase todos os hoteis analisados.

# %%
sns.relplot(
    x='ano_avaliacao',
    y='rating',
    col='source',
    kind="line",
    col_wrap=3,
    data=analisar_df,
)
plt.show()

# %% [markdown]
# exemplo de algumas avaliações

# %%
analisar_df[['rating', 'text', 'data_avaliacao', 'user_is_local_guide', 'user_reviews', 'source']].head()
# Out:
#     rating                                text data_avaliacao  \
# 2      5.0  Lugar fantástico, recomendo super.     2023-07-06
# 5      5.0                       Tudo perfeito     2023-07-06
# 16     5.0                          excelente!     2023-07-06
# 17     5.0                         Belo lugar.     2023-07-06
# 19     5.0                         Ótimo local     2023-07-06
#
#    user_is_local_guide user_reviews                     source
# 2                False            9  hotel-marsol-beach-resort
# 5                 True           36  hotel-marsol-beach-resort
# 16                True           52  hotel-marsol-beach-resort
# 17                True           41  hotel-marsol-beach-resort
# 19               False            7  hotel-marsol-beach-resort

# %% [markdown]
# ### WordCloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import string

# Concatenar todos os textos em uma única string
texto = ' '.join(analisar_df['text'].tolist())

# Tokenização das palavras
tokens = word_tokenize(texto)

# Obtenha as stopwords em português
stopwords_pt = set(stopwords.words('portuguese'))

# Remova as stopwords do texto
tokens_sem_pontuacao = [token.translate(str.maketrans('', '', string.punctuation)) for token in tokens]
tokens_sem_stopwords = [token for token in tokens_sem_pontuacao if token.lower() not in stopwords_pt]
# Junte as palavras novamente em um texto
texto_sem_stopwords = ' '.join(tokens_sem_stopwords)

# Criar um objeto WordCloud com as configurações desejadas
wc = WordCloud(background_color='white', max_words=1000, width=800, height=400)

# Gerar a nuvem de palavras
nuvem = wc.generate(texto_sem_stopwords)

# Exibir a nuvem de palavras
plt.imshow(nuvem, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from nltk.probability import FreqDist
palavras = texto_sem_stopwords.split()

contagem = FreqDist(palavras)

contagem.plot(25)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
#Create your bigrams
bgs = nltk.bigrams(palavras)

#compute frequency distribution for all the bigrams in the text
fdist = FreqDist(bgs)
fdist.plot(25)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ## NOVO timechart

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import string

def frequencia_ano(df, source, ano):
  filter = (df['ano_avaliacao'] == ano)
  #  (df['source']  == source) &
  # Concatenar todos os textos em uma única string
  texto = ' '.join(analisar_df[filter]['text'].tolist())

  # Tokenização das palavras
  tokens = word_tokenize(texto)
  #
  # Obtenha as stopwords em português
  stopwords_pt = set(stopwords.words('portuguese'))
  #
  # Remova as stopwords do texto
  tokens_sem_pontuacao = [token.translate(str.maketrans('', '', string.punctuation)) for token in tokens]
  tokens_sem_stopwords = [token for token in tokens_sem_pontuacao if token.lower() not in stopwords_pt]
  # Junte as palavras novamente em um texto
  texto_sem_stopwords = ' '.join(tokens_sem_stopwords)
  from nltk.probability import FreqDist
  palavras = texto_sem_stopwords.split()

  contagem = FreqDist(palavras)

  result = pd.DataFrame(contagem.items(), columns=['word', 'frequency'])
  result[ano] = result['frequency']
  return result[['word', ano]]

# %%
from functools import reduce
anos = [2018, 2019, 2020, 2021, 2022, 2023]
source = True
datasets = reduce(lambda left, right: pd.merge(left, right, on='word', how='outer'), map(lambda ano: frequencia_ano(analisar_df, source, ano), anos)).fillna(0)

# %%
datasets.head()
# Out:
#         word   2018   2019   2020   2021   2022   2023
# 0       Café   28.0   35.0   25.0   37.0   83.0   49.0
# 1      manhã  148.0  218.0  136.0  189.0  400.0  289.0
# 2       nada  140.0  196.0  139.0  224.0  451.0  228.0
# 3  agradável  193.0  219.0  144.0  139.0  252.0  240.0
# 4     Faltam    4.0    7.0    2.0    1.0   14.0    2.0

# %%
df_long = pd.melt(datasets, id_vars='word', var_name='year', value_name='value')
df_long
# Out:
#                word  year  value
# 0              Café  2018   28.0
# 1             manhã  2018  148.0
# 2              nada  2018  140.0
# 3         agradável  2018  193.0
# 4            Faltam  2018    4.0
# ...             ...   ...    ...
# 224077        Jaina  2023    1.0
# 224078       dançou  2023    1.0
# 224079  polivalente  2023    1.0
# 224080      Jefinho  2023    1.0
# 224081     Tarcísio  2023    1.0
#
# [224082 rows x 3 columns]

# %%
from datetime import date

keep = []
df_month = df_long.copy()
for i in anos:
    aux = df_month[df_month['year']==i].copy()
    order = aux['value'].rank(ascending=False)
    aux['rank'] = [int(i) for i in order]
    keep.append(aux)

df_month = pd.concat(keep)
df_month.sort_values(['year', 'word'], ascending=True,
                     inplace=True, ignore_index=True)

top_20 = df_month[df_month['rank'] < 11]
top_20.head()
# Out:
#               word  year  value  rank
# 4943     Excelente  2018  648.0     7
# 7049         Lugar  2018  586.0     8
# 13828  atendimento  2018  740.0     3
# 14608          bem  2018  553.0     9
# 14760          boa  2018  654.0     6

# %%
top_20.to_csv(f'/content/gdrive/MyDrive/tcc/exploratoria/tokens/{name}-top-20.csv', index=False)
df_month.to_csv(f'/content/gdrive/MyDrive/tcc/exploratoria/tokens/{name}-df-month.csv', index=False)

# %%
#extract color palette, the palette can be changed
list_dist = list(set(top_20['word']))
pal = list(sns.color_palette(palette='Spectral',
                             n_colors=len(list_dist)).as_hex())
dict_color = dict(zip(list_dist, pal))

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Reshape the DataFrame to long format
df_long = datasets.head(30).melt(id_vars='word', var_name='year', value_name='value')

# Create the line plot
plt.figure(figsize=(10, 6))
for word in df_long['word'].unique():
    word_data = df_long[df_long['word'] == word]
    plt.plot(word_data['year'], word_data['value'], label=word, marker='o', linestyle='-', linewidth=2)

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Word Frequency Over Years (Line Plot)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# https://towardsdatascience.com/7-visualizations-with-python-to-express-changes-in-rank-over-time-71c1f11d7e4b

# %%
ym = list(anos)
ym.sort()

top_20['posi'] = [ym.index(i) for i in top_20['year']]
top_20['value_str'] = [str(round(i,2)) for i in top_20['value']]
top_20['value_text'] = top_20['value_str']
# Out:
# <ipython-input-53-12ac7ceb78c2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_20['posi'] = [ym.index(i) for i in top_20['year']]
# <ipython-input-53-12ac7ceb78c2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_20['value_str'] = [str(round(i,2)) for i in top_20['value']]
# <ipython-input-53-12ac7ceb78c2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_20['value_text'] = top_20['value_str']

# %%
import plotly.express as px
fig = px.scatter(top_20, x='posi', y='rank',
                 size= 'value',
                 color='word', text='value_text',
                 color_discrete_map= dict_color,
                 animation_frame='year',
                 animation_group='word',
                 range_x=[-2,len(ym)],
                 range_y=[0.5,6.5]
                )
fig.update_xaxes(title='', visible=False)
fig.update_yaxes(autorange='reversed', title='Rank',
                 visible=True, showticklabels=True)
fig.update_layout(xaxis=dict(showgrid=False),
                  yaxis=dict(showgrid=True))
fig.update_traces(textposition='middle left')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3fc50e17-a408-4d3c-a7c6-54c7bbabc061" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3fc50e17-a408-4d3c-a7c6-54c7bbabc061")) {                    Plotly.newPlot(                        "3fc50e17-a408-4d3c-a7c6-54c7bbabc061",                        [{"hovertemplate":"word=Excelente<br>year=2018<br>posi=%{x}<br>rank=%{y}<br>value=%{marker.size}<br>value_text=%{text}<extra></extra>","ids":["Excelente"],"legendgroup":"Excelente","marker":{"color":"#ba2049","size":[648.0],"sizemode":"area","sizeref":5.53,"symbol":"circle"},"mode":"markers+text","name":"Excelente","orientation":"v","showlegend":true,"text":["648.0"],"x":[0],"xaxis":"x","y":[7],"yaxis":"y","type":"scatter","textposition":"middle left"},{"hovertemplate":"word=Lugar<br>year=2018<br>posi=%{x}<br>rank=%{y}<br>value=%{marker.size}<br>value_text=%{text}<extra></extra>","ids":["Lugar"],"legendgroup":"Lugar","marker":{"color":"#f9fcb5","size":[586.0],"sizemode":"area","sizeref":5.53,"symbol":"circle"},"mode":"markers+text","name":"Lugar","orientation":"v","showlegend":true,"text":["586.0"],"x":[0],"xaxis":"x","y":[8],"yaxis":"y","type":"scatter","textposition":"middle left"},{"hovertemplate":"word=atendimento<br>year=2018<br>posi=%{x}<br>rank=%{y}<br>value=%{marker.size}<br>value_text=%{text}<extra></extra>","ids":["atendimento"],"legendgroup":"atendimento","marker":{"color":"#d63f4f","size":[740.0],"sizemode":"area","sizeref":5.53,"symbol":"circle"},"mode":"markers+text","name":"atendimento","orientation":"v","showlegend":true,"text":["740.0"],"x":[0],"xaxis":"x","y":[3],"yaxis":"y","type":"scatter","textposition":"middle left"},{"hovertemplate":"word=bem<br>year=2018<br>posi=%{x}<br>rank=%{y}<br>value=%{marker.size}<br>value_text=%{text}<extra></extra>","ids":["bem"],"legendgroup":"bem","marker":{"color":"#486cb0","size":[553.0],"sizemode":"area","sizeref":5.53,"symbol":"circle"},"mode":"markers+text","name":"bem","orientation":"v","showlegend":true,"text":["553.0"],"x":[0],"xaxis":"x","y":[9],"yaxis":"y","type":"scatter","textposition":"middle left"},{"hovertemplate":"word=boa<br>year=2018<br>posi=%{x}<br>rank=%{y}<br>value=%{marker.size}<br>value_text=%{text}<extra></extra>","ids":["boa"],"legendgroup":"boa","marker":{"color":"#fdb567","size":[654.0],"sizemode":"area","sizeref":5.53,"symbol":"circle"},"mode":"markers+text","name":"boa","orientation":"v","showlegend":true,"text":["654.0"],"x":[0],"xaxis":"x","y":[6],"yaxis":"y","type":"scatter","textposition":"middle left"},{"hovertemplate":"word=bom<br>year=2018<br>posi=%{x}<br>rank=%{y}<br>value=%{marker.size}<br>value_text=%{text}<extra></extra>","ids":["bom"],"legendgroup":"bom","marker":{"color":"#fee695","size":[1195.0],"sizemode":"area","sizeref":5.53,"symbol":"circle"},"mode":"markers+text","name":"bom","orientation":"v","showlegend":true,"text":["1195.0"],"x":[0],"xaxis":"x","y":[1],"yaxis":"y","type":"scatter","textposition":"middle left"},{"hovertemplate":"word=comida<br>year=2018<br>posi=%{x}<br>rank=%{y}<br>value=%{marker.size}<br>value_text=%{text}<extra></extra>","ids":["comida"],"legendgroup":"comida","marker":{"color":"#b3e0a2","size":[787.0],"sizemode":"area","sizeref":5.53,"symbol":"circle"},"mode":"markers+text","name":"comida","orientation":"v","showlegend":true,"text":["787.0"],"x":[0],"xaxis":"x","y":[2],"yaxis":"y","type":"scatter","textposition":"middle left"},{"hovertemplate":"word=hotel<br>year=2018<br>posi=%{x}<br>rank=%{y}<br>value=%{marker.size}<br>value_text=%{text}<extra></extra>","ids":["hotel"],"legendgroup":"hotel","marker":{"color":"#d3ed9c","size":[721.0],"sizemode":"area","sizeref":5.53,"symbol":"circle"},"mode":"markers+text","name":"hotel","orientation":"v","showlegend":true,"text":["721.0 ...

# %%
import plotly.express as px
fig = px.line(top_20, x = 'year', y = 'rank',
              color = 'word',
              color_discrete_map= dict_color,
              markers=True,
              hover_name = 'value_text')
fig.update_traces(marker=dict(size=11))
fig.update_yaxes(autorange='reversed', title='Rank',
                 visible=True, showticklabels=True)
fig.update_xaxes(title='', visible=True, showticklabels=True)
fig.update_layout(xaxis=dict(showgrid=False),
                  yaxis=dict(showgrid=False) )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="64fb1353-d0e3-4106-971a-95a5fb59aca4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64fb1353-d0e3-4106-971a-95a5fb59aca4")) {                    Plotly.newPlot(                        "64fb1353-d0e3-4106-971a-95a5fb59aca4",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>word=Excelente<br>year=%{x}<br>rank=%{y}<extra></extra>","hovertext":["648.0","957.0"],"legendgroup":"Excelente","line":{"color":"#ba2049","dash":"solid"},"marker":{"symbol":"circle","size":11},"mode":"lines+markers","name":"Excelente","orientation":"v","showlegend":true,"x":[2018,2019],"xaxis":"x","y":[7,6],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>word=Lugar<br>year=%{x}<br>rank=%{y}<extra></extra>","hovertext":["586.0","884.0","577.0"],"legendgroup":"Lugar","line":{"color":"#f9fcb5","dash":"solid"},"marker":{"symbol":"circle","size":11},"mode":"lines+markers","name":"Lugar","orientation":"v","showlegend":true,"x":[2018,2019,2020],"xaxis":"x","y":[8,8,7],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>word=atendimento<br>year=%{x}<br>rank=%{y}<extra></extra>","hovertext":["740.0","1143.0","745.0","1030.0","1940.0","1273.0"],"legendgroup":"atendimento","line":{"color":"#d63f4f","dash":"solid"},"marker":{"symbol":"circle","size":11},"mode":"lines+markers","name":"atendimento","orientation":"v","showlegend":true,"x":[2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[3,3,3,1,3,6],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>word=bem<br>year=%{x}<br>rank=%{y}<extra></extra>","hovertext":["553.0","915.0","611.0","844.0","2011.0","1471.0"],"legendgroup":"bem","line":{"color":"#486cb0","dash":"solid"},"marker":{"symbol":"circle","size":11},"mode":"lines+markers","name":"bem","orientation":"v","showlegend":true,"x":[2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[9,7,6,4,2,4],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>word=boa<br>year=%{x}<br>rank=%{y}<extra></extra>","hovertext":["654.0","877.0","557.0","623.0","1559.0"],"legendgroup":"boa","line":{"color":"#fdb567","dash":"solid"},"marker":{"symbol":"circle","size":11},"mode":"lines+markers","name":"boa","orientation":"v","showlegend":true,"x":[2018,2019,2020,2021,2022],"xaxis":"x","y":[6,9,9,9,8],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>word=bom<br>year=%{x}<br>rank=%{y}<extra></extra>","hovertext":["1195.0","1607.0","978.0","888.0","1887.0","1403.0"],"legendgroup":"bom","line":{"color":"#fee695","dash":"solid"},"marker":{"symbol":"circle","size":11},"mode":"lines+markers","name":"bom","orientation":"v","showlegend":true,"x":[2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[1,1,1,3,4,5],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>word=comida<br>year=%{x}<br>rank=%{y}<extra></extra>","hovertext":["787.0","1213.0","830.0","960.0","2212.0","1135.0"],"legendgroup":"comida","line":{"color":"#b3e0a2","dash":"solid"},"marker":{"symbol":"circle","size":11},"mode":"lines+markers","name":"comida","orientation":"v","showlegend":true,"x":[2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[2,2,2,2,1,9],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>word=hotel<br>year=%{x}<br>rank=%{y}<extra></extra>","hovertext":["721.0","962.0","714.0","740.0","1755.0","1522.0"],"legendgroup":"hotel","line":{"color":"#d3ed9c","dash":"solid"},"marker":{"symbol":"circle","size":11},"mode":"lines+markers","name":"hotel","orientation":"v","showlegend":true,"x":[2018,2019,2020,2021,2022,2023],"xaxis":"x","y":[5,5,5,6,5,2],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>word=lugar<br>year=%{x}<br>rank= ...

# %%
datasets[datasets['word'] == 'bebida']
# Out:
#        word  2018   2019   2020   2021   2022   2023
# 843  bebida  94.0  173.0  130.0  145.0  441.0  179.0

# %%
# Criar o gráfico de dispersão usando o Seaborn
plt.figure(figsize=(10, 6))  # Definir o tamanho da figura
scatter_plot = sns.scatterplot(data=datasets, x='year', y='word', size='frequency', sizes=(30, 300), legend=False)

# Adicionar rótulos de frequência aos pontos
for _, row in datasets.iterrows():
    scatter_plot.text(row['word'], row['year'], row['frequency'], ha='center', va='center', fontsize=9)

# Definir título e rótulos dos eixos
plt.title('Frequência das palavras por ano')
plt.xlabel('Palavra')
plt.ylabel('Ano')

# Girar os rótulos do eixo X para melhor legibilidade
plt.xticks(rotation=45, ha='right')

# Exibir o gráfico
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-5e1376ce8b69> in <cell line: 3>()
#       1 # Criar o gráfico de dispersão usando o Seaborn
#       2 plt.figure(figsize=(10, 6))  # Definir o tamanho da figura
# ----> 3 scatter_plot = sns.scatterplot(data=datasets, x='year', y='word', size='frequency', sizes=(30, 300), legend=False)
#       4
#       5 # Adicionar rótulos de frequência aos pontos
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     740
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     743
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     536         )
#     537
# --> 538         super().__init__(data=data, variables=variables)
#     539
#     540         self.legend = legend
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py in __init__(self, data, variables)
#     638         # information for numeric axes would be information about log scales.
#     639         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640         self.assign_variables(data, variables)
#     641
#     642         for var, cls in self._semantic_mappings.items():
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py in assign_variables(self, data, variables)
#     699         else:
#     700             self.input_format = "long"
# --> 701             plot_data, variables = self._assign_variables_longform(
#     702                 data, **variables,
#     703             )
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py in _assign_variables_longform(self, data, **kwargs)
#     936
#     937                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938                 raise ValueError(err)
#     939
#     940             else:
#
# ValueError: Could not interpret value `year` for parameter `x`

# %%
# Criar o gráfico de barras para visualizar a frequência dos n-grams ao longo do tempo
plt.figure(figsize=(12, 6))
sns.barplot(data=datasets, x='year', y='frequency', hue='word')
plt.title(f'Frequência por ano')
plt.xlabel('Ano')
plt.ylabel('Frequência')
plt.legend(title='N-gram')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-5e42ecaa0008> in <cell line: 3>()
#       1 # Criar o gráfico de barras para visualizar a frequência dos n-grams ao longo do tempo
#       2 plt.figure(figsize=(12, 6))
# ----> 3 sns.barplot(data=datasets, x='year', y='frequency', hue='word')
#       4 plt.title(f'Frequência por ano')
#       5 plt.xlabel('Ano')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2753         estimator = "size"
#    2754
# -> 2755     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                           estimator, errorbar, n_boot, units, seed,
#    2757                           orient, color, palette, saturation,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1528                  errcolor, errwidth, capsize, dodge):
#    1529         """Initialize the plotter."""
# -> 1530         self.establish_variables(x, y, hue, data, orient,
#    1531                                  order, hue_order, units)
#    1532         self.establish_colors(color, palette, saturation)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539                 if isinstance(var, str):
#     540                     err = f"Could not interpret input '{var}'"
# --> 541                     raise ValueError(err)
#     542
#     543             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'year'

# %%
sns.relplot(x='ano_avaliacao', y='rating', kind="line", data=analisar_df[analisar_df['source']  == source])
