# %% [markdown]
# <a href="https://colab.research.google.com/github/emerson-matos/tcc-notebooks/blob/main/sentimentos/notebook_bert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !nvidia-smi
# Out:
# Fri Oct  6 21:19:41 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.113.01             Driver Version: 535.113.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4070 Ti     Off | 00000000:08:00.0  On |                  N/A |
# |  0%   46C    P3              34W / 285W |    886MiB / 12282MiB |     46%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
from google.colab import drive

drive.mount('/content/gdrive')

# %%
date = '2023-09-01'
filename = 'analisar.csv'
dados = pd.read_csv(f"/content/gdrive/MyDrive/tcc/exploratoria/{date}-{filename}")

dados.head()[['text', 'source', 'data_avaliacao']]
# Out:
#                                  text                     source  \
# 0  Lugar fantástico, recomendo super.  hotel-marsol-beach-resort
# 1                       Tudo perfeito  hotel-marsol-beach-resort
# 2                          excelente!  hotel-marsol-beach-resort
# 3                         Belo lugar.  hotel-marsol-beach-resort
# 4                         Ótimo local  hotel-marsol-beach-resort
#
#   data_avaliacao
# 0     2023-07-06
# 1     2023-07-06
# 2     2023-07-06
# 3     2023-07-06
# 4     2023-07-06

# %%
treinado = pd.read_csv(f"/content/gdrive/MyDrive/tcc/testando-classificacao.csv")

treinado.head()[['text', 'source', 'data_avaliacao']]
# Out:
#                                  text    source data_avaliacao
# 0  Lugar fantástico, recomendo super.  analisar     2023-07-06
# 1                       Tudo perfeito  analisar     2023-07-06
# 2                          excelente!  analisar     2023-07-06
# 3                         Belo lugar.  analisar     2023-07-06
# 4                         Ótimo local  analisar     2023-07-06

# %%
dados.describe()
# Out:
#              rating         likes  mes_avaliacao  ano_avaliacao
# count  49219.000000  49219.000000   49219.000000   49219.000000
# mean       4.604787      0.166623       6.790650    2020.699181
# std        0.895289      0.731727       1.524495       1.746374
# min        1.000000      0.000000       1.000000    2018.000000
# 25%        5.000000      0.000000       7.000000    2019.000000
# 50%        5.000000      0.000000       7.000000    2021.000000
# 75%        5.000000      0.000000       7.000000    2022.000000
# max        5.000000     25.000000      12.000000    2023.000000

# %% [markdown]
# # 08

# %%
# !pip install transformers[sentencepiece] datasets
# Out:
# Collecting transformers[sentencepiece]
#   Downloading transformers-4.33.3-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 38.8 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 89.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers[sentencepiece])
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 85.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers[sentencepiece])
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.5 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers[sentencepiece])
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 98.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (4.65.0)
# Collecting sentencepiece!=0.1.92,>=0.1.91 (from transformers[sentencepiece])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 93.1 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 63.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 86.5 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 70.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers[sentencepiece]) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[sentencepiece]) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: tokenizers, sentencepiece, safetensors, xxhash, dill, multiprocess, huggingface-hub, transformers, datasets
# Successfully installed datasets-2.14.5 dill-0.3.7 huggingface-hub-0.17.3 multiprocess-0.70.15 safetensors-0.3.3 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.33.3 xxhash-3.3.0

# %% [markdown]
# ## bert pre treinado

# %%
sentences = [
  'Foi muito bom, exceto o primeiro atendimento na recepção na chegada, fizemos o chek-in e não nos informaram onde ficaria o nosso chalé, tivemos que ficar perguntando a alguns funcionários, fora isso tudo de bom.',
  'Lindo d mais',
  'Muito bom. Vale o valor pago',
  'Tudo perfeito',
  'Drinks muito bom',
  'Incrível',
  'Foi ótimo dias maravilhosos...',
  'Passagem incrível.  Boa comida.  Piscinas amplas com águas mornas.',
  'Alimentação péssima! Do mais tudo ok!',
  'Muito sofisticado',
  'Otima',
  'Lugar fantástico, recomendo super.',
  'Estou deslumbrado com a beleza ,ao entorno do hotel ,quarto amplo e confortável ,a piscina espetacular ,foi uma experiência incrível!!!'
]

# %%
import torch
from transformers import AutoTokenizer  # Or BertTokenizer
from transformers import AutoModelForSequenceClassification  # Or BertForPreTraining for loading pretraining heads
from transformers import pipeline


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

teste = dados.copy()

teste.head(5)
# Out:
#                retrieval_date  rating   relative_date  likes  \
# 0  2023-07-07 00:33:49.096786     5.0  10 horas atrás      0
# 1  2023-07-07 00:33:49.185915     5.0  10 horas atrás      0
# 2  2023-07-07 00:33:50.064473     5.0  11 horas atrás      0
# 3  2023-07-07 00:33:50.080896     5.0  11 horas atrás      0
# 4  2023-07-07 00:33:50.109826     5.0  11 horas atrás      0
#
#   user_is_local_guide                                text  \
# 0               False  Lugar fantástico, recomendo super.
# 1                True                       Tudo perfeito
# 2                True                          excelente!
# 3                True                         Belo lugar.
# 4               False                         Ótimo local
#
#                       source user_reviews data_avaliacao  mes_avaliacao  \
# 0  hotel-marsol-beach-resort            9     2023-07-06              7
# 1  hotel-marsol-beach-resort           36     2023-07-06              7
# 2  hotel-marsol-beach-resort           52     2023-07-06              7
# 3  hotel-marsol-beach-resort           41     2023-07-06              7
# 4  hotel-marsol-beach-resort            7     2023-07-06              7
#
#    ano_avaliacao mes_ano_avaliacao  com_texto  nao_vazio  traduzido  \
# 0           2023           2023-07       True       True      False
# 1           2023           2023-07       True       True      False
# 2           2023           2023-07       True       True      False
# 3           2023           2023-07       True       True      False
# 4           2023           2023-07       True       True      False
#
#    depois_2017  analisar
# 0         True      True
# 1         True      True
# 2         True      True
# 3         True      True
# 4         True      True

# %%
PRE_TRAINED_MODEL_NAME_1 = 'philschmid/distilbert-base-multilingual-cased-sentiment'

tokenizer1 = AutoTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME_1, do_lower_case=False)
model1 = AutoModelForSequenceClassification.from_pretrained(PRE_TRAINED_MODEL_NAME_1).to(device)
classifier1 = pipeline('sentiment-analysis',
                      model=model1,
                      tokenizer=tokenizer1,
                      max_length=512,
                      truncation=True,
                      pad_to_max_length=True,
                      device=device,
                      framework="pt",
                      batch_size=16,
)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/345 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/814 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/541M [00:00<?, ?B/s]

# %%
classifier1(sentences)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2418: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# [{'label': 'negative', 'score': 0.9226691722869873},
#  {'label': 'neutral', 'score': 0.4194216728210449},
#  {'label': 'negative', 'score': 0.8745064735412598},
#  {'label': 'positive', 'score': 0.9701987504959106},
#  {'label': 'negative', 'score': 0.7377951145172119},
#  {'label': 'negative', 'score': 0.5013454556465149},
#  {'label': 'negative', 'score': 0.4844314754009247},
#  {'label': 'neutral', 'score': 0.5337896943092346},
#  {'label': 'negative', 'score': 0.9250680804252625},
#  {'label': 'neutral', 'score': 0.42814022302627563},
#  {'label': 'positive', 'score': 0.8648582696914673},
#  {'label': 'positive', 'score': 0.9849022030830383},
#  {'label': 'positive', 'score': 0.9673092365264893}]

# %%
PRE_TRAINED_MODEL_NAME_2 = 'lxyuan/distilbert-base-multilingual-cased-sentiments-student'

tokenizer2 = AutoTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME_2, do_lower_case=False)
model2 = AutoModelForSequenceClassification.from_pretrained(PRE_TRAINED_MODEL_NAME_2).to(device)
classifier2 = pipeline('sentiment-analysis',
                      model=model2,
                      tokenizer=tokenizer2,
                      max_length=512,
                      truncation=True,
                      pad_to_max_length=True,
                      device=device,
                      framework="pt",
                      batch_size=16,
)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/759 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]

# %%
classifier2(sentences)
# Out:
# [{'label': 'negative', 'score': 0.5495229959487915},
#  {'label': 'positive', 'score': 0.5910864472389221},
#  {'label': 'positive', 'score': 0.8239201903343201},
#  {'label': 'negative', 'score': 0.6602097749710083},
#  {'label': 'positive', 'score': 0.5783613920211792},
#  {'label': 'positive', 'score': 0.533176600933075},
#  {'label': 'positive', 'score': 0.9308533072471619},
#  {'label': 'positive', 'score': 0.7248801589012146},
#  {'label': 'positive', 'score': 0.7259961366653442},
#  {'label': 'negative', 'score': 0.5079984664916992},
#  {'label': 'positive', 'score': 0.5399190783500671},
#  {'label': 'positive', 'score': 0.9592684507369995},
#  {'label': 'negative', 'score': 0.7474359273910522}]

# %%
PRE_TRAINED_MODEL_NAME_3 = 'citizenlab/twitter-xlm-roberta-base-sentiment-finetunned'

tokenizer3 = AutoTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME_3, do_lower_case=False)
model3 = AutoModelForSequenceClassification.from_pretrained(PRE_TRAINED_MODEL_NAME_3).to(device)
classifier3 = pipeline('sentiment-analysis',
                      model=model3,
                      tokenizer=tokenizer3,
                      max_length=512,
                      truncation=True,
                      pad_to_max_length=True,
                      device=device,
                      framework="pt",
                      batch_size=16,
)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/618 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/992 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]

# %%
classifier3(sentences)
# Out:
# [{'label': 'Positive', 'score': 0.9781147837638855},
#  {'label': 'Positive', 'score': 0.9915336966514587},
#  {'label': 'Positive', 'score': 0.9922174215316772},
#  {'label': 'Positive', 'score': 0.9922283291816711},
#  {'label': 'Positive', 'score': 0.9896873831748962},
#  {'label': 'Positive', 'score': 0.9074751734733582},
#  {'label': 'Positive', 'score': 0.9909008741378784},
#  {'label': 'Positive', 'score': 0.9921296238899231},
#  {'label': 'Negative', 'score': 0.9787968397140503},
#  {'label': 'Negative', 'score': 0.9137847423553467},
#  {'label': 'Positive', 'score': 0.9924835562705994},
#  {'label': 'Positive', 'score': 0.9925462603569031},
#  {'label': 'Positive', 'score': 0.99159836769104}]

# %%
PRE_TRAINED_MODEL_NAME_4 = 'cardiffnlp/twitter-xlm-roberta-base-sentiment'

tokenizer4 = AutoTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME_4, do_lower_case=False)
model4 = AutoModelForSequenceClassification.from_pretrained(PRE_TRAINED_MODEL_NAME_4).to(device)
classifier4 = pipeline('sentiment-analysis',
                      model=model4,
                      tokenizer=tokenizer4,
                      max_length=512,
                      truncation=True,
                      pad_to_max_length=True,
                      device=device,
                      framework="pt",
                      batch_size=16,
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/841 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]

# %%
classifier4(sentences)
# Out:
# [{'label': 'positive', 'score': 0.5777750015258789},
#  {'label': 'positive', 'score': 0.8819499611854553},
#  {'label': 'positive', 'score': 0.9002392888069153},
#  {'label': 'positive', 'score': 0.8660373091697693},
#  {'label': 'positive', 'score': 0.8850589990615845},
#  {'label': 'positive', 'score': 0.695933997631073},
#  {'label': 'positive', 'score': 0.9281375408172607},
#  {'label': 'positive', 'score': 0.9304505586624146},
#  {'label': 'negative', 'score': 0.9328173398971558},
#  {'label': 'negative', 'score': 0.4048030972480774},
#  {'label': 'positive', 'score': 0.6601681113243103},
#  {'label': 'positive', 'score': 0.9392898678779602},
#  {'label': 'positive', 'score': 0.9188212156295776}]

# %%
PRE_TRAINED_MODEL_NAME_5 = 'ramonmedeiro1/bertimbau-products-reviews-pt-br'

tokenizer5 = AutoTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME_5, do_lower_case=False)
model5 = AutoModelForSequenceClassification.from_pretrained(PRE_TRAINED_MODEL_NAME_5).to(device)
classifier5 = pipeline('sentiment-analysis',
                      model=model5,
                      tokenizer=tokenizer5,
                      max_length=512,
                      truncation=True,
                      pad_to_max_length=True,
                      device=device,
                      framework="pt",
                      batch_size=16,
)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/585 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/210k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/678k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.16k [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]

# %%
classifier5(sentences)
# Out:
# [{'label': 'Positivo', 'score': 0.5946270823478699},
#  {'label': 'Muito Positivo', 'score': 0.9520754218101501},
#  {'label': 'Positivo', 'score': 0.5735266208648682},
#  {'label': 'Muito Positivo', 'score': 0.8999791145324707},
#  {'label': 'Positivo', 'score': 0.5460475087165833},
#  {'label': 'Muito Positivo', 'score': 0.9668323993682861},
#  {'label': 'Muito Positivo', 'score': 0.8012335896492004},
#  {'label': 'Muito Positivo', 'score': 0.9259946942329407},
#  {'label': 'Negativo', 'score': 0.6605251431465149},
#  {'label': 'Muito Positivo', 'score': 0.8711700439453125},
#  {'label': 'Muito Positivo', 'score': 0.4971369802951813},
#  {'label': 'Muito Positivo', 'score': 0.936265766620636},
#  {'label': 'Muito Positivo', 'score': 0.9635603427886963}]

# %%
MODELS = [PRE_TRAINED_MODEL_NAME_1,PRE_TRAINED_MODEL_NAME_2,PRE_TRAINED_MODEL_NAME_3,PRE_TRAINED_MODEL_NAME_4,PRE_TRAINED_MODEL_NAME_5]

# %%
treinado.head()
# Out:
#                retrieval_date  rating   relative_date  likes  \
# 0  2023-07-07 00:33:49.096786     5.0  10 horas atrás      0
# 1  2023-07-07 00:33:49.185915     5.0  10 horas atrás      0
# 2  2023-07-07 00:33:50.064473     5.0  11 horas atrás      0
# 3  2023-07-07 00:33:50.080896     5.0  11 horas atrás      0
# 4  2023-07-07 00:33:50.109826     5.0  11 horas atrás      0
#
#   user_is_local_guide                                text    source  \
# 0               False  Lugar fantástico, recomendo super.  analisar
# 1                True                       Tudo perfeito  analisar
# 2                True                          excelente!  analisar
# 3                True                         Belo lugar.  analisar
# 4               False                         Ótimo local  analisar
#
#   user_reviews data_avaliacao  mes_avaliacao  ano_avaliacao mes_ano_avaliacao  \
# 0            9     2023-07-06              7           2023           2023-07
# 1           36     2023-07-06              7           2023           2023-07
# 2           52     2023-07-06              7           2023           2023-07
# 3           41     2023-07-06              7           2023           2023-07
# 4            7     2023-07-06              7           2023           2023-07
#
#    com_texto  nao_vazio  traduzido  depois_2017  analisar  \
# 0       True       True      False         True      True
# 1       True       True      False         True      True
# 2       True       True      False         True      True
# 3       True       True      False         True      True
# 4       True       True      False         True      True
#
#                         text_truncado sentiment_bert
# 0  Lugar fantástico, recomendo super.       positive
# 1                       Tudo perfeito       negative
# 2                          excelente!       positive
# 3                         Belo lugar.       positive
# 4                         Ótimo local       positive

# %%
from datasets import Dataset
dataset = Dataset.from_pandas(teste)

# %%
# %%time
dataset = dataset.map(lambda x: {MODELS[0]: classifier1(x['text'])}, batched=True)
# Out:
# Map:   0%|          | 0/49219 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2418: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# CPU times: user 3min 37s, sys: 575 ms, total: 3min 37s
# Wall time: 3min 37s

# %%
# %%time
dataset = dataset.map(lambda x: {MODELS[1]: classifier2(x['text'])}, batched=True)
# Out:
# Map:   0%|          | 0/49219 [00:00<?, ? examples/s]
# CPU times: user 3min 36s, sys: 242 ms, total: 3min 36s
# Wall time: 3min 36s

# %%
# %%time
dataset = dataset.map(lambda x: {MODELS[2]: classifier3(x['text'])}, batched=True)
# Out:
# Map:   0%|          | 0/49219 [00:00<?, ? examples/s]
# CPU times: user 6min 55s, sys: 259 ms, total: 6min 55s
# Wall time: 6min 54s

# %%
# %%time
dataset = dataset.map(lambda x: {MODELS[3]: classifier4(x['text'])}, batched=True)
# Out:
# Map:   0%|          | 0/49219 [00:00<?, ? examples/s]
# CPU times: user 6min 44s, sys: 333 ms, total: 6min 45s
# Wall time: 6min 44s

# %%
# %%time
dataset = dataset.map(lambda x: {MODELS[4]: classifier5(x['text'])}, batched=True)
# Out:
# Map:   0%|          | 0/49219 [00:00<?, ? examples/s]
# CPU times: user 6min 59s, sys: 229 ms, total: 6min 59s
# Wall time: 6min 59s

# %%
dataset[0]
# Out:
# {'retrieval_date': '2023-07-07 00:33:49.096786',
#  'rating': 5.0,
#  'relative_date': '10 horas atrás',
#  'likes': 0,
#  'user_is_local_guide': False,
#  'text': 'Lugar fantástico, recomendo super.',
#  'source': 'hotel-marsol-beach-resort',
#  'user_reviews': '9',
#  'data_avaliacao': '2023-07-06',
#  'mes_avaliacao': 7,
#  'ano_avaliacao': 2023,
#  'mes_ano_avaliacao': '2023-07',
#  'com_texto': True,
#  'nao_vazio': True,
#  'traduzido': False,
#  'depois_2017': True,
#  'analisar': True,
#  'philschmid/distilbert-base-multilingual-cased-sentiment': {'label': 'positive',
#   'score': 0.9849022030830383},
#  'lxyuan/distilbert-base-multilingual-cased-sentiments-student': {'label': 'positive',
#   'score': 0.9592684507369995},
#  'citizenlab/twitter-xlm-roberta-base-sentiment-finetunned': {'label': 'Positive',
#   'score': 0.9925462603569031},
#  'cardiffnlp/twitter-xlm-roberta-base-sentiment': {'label': 'positive',
#   'score': 0.9392898678779602},
#  'ramonmedeiro1/bertimbau-products-reviews-pt-br': {'label': 'Muito Positivo',
#   'score': 0.936265766620636}}

# %%
teste = dataset.to_pandas()

teste.head(5)
# Out:
#                retrieval_date  rating   relative_date  likes  \
# 0  2023-07-07 00:33:49.096786     5.0  10 horas atrás      0
# 1  2023-07-07 00:33:49.185915     5.0  10 horas atrás      0
# 2  2023-07-07 00:33:50.064473     5.0  11 horas atrás      0
# 3  2023-07-07 00:33:50.080896     5.0  11 horas atrás      0
# 4  2023-07-07 00:33:50.109826     5.0  11 horas atrás      0
#
#   user_is_local_guide                                text  \
# 0               False  Lugar fantástico, recomendo super.
# 1                True                       Tudo perfeito
# 2                True                          excelente!
# 3                True                         Belo lugar.
# 4               False                         Ótimo local
#
#                       source user_reviews data_avaliacao  mes_avaliacao  ...  \
# 0  hotel-marsol-beach-resort            9     2023-07-06              7  ...
# 1  hotel-marsol-beach-resort           36     2023-07-06              7  ...
# 2  hotel-marsol-beach-resort           52     2023-07-06              7  ...
# 3  hotel-marsol-beach-resort           41     2023-07-06              7  ...
# 4  hotel-marsol-beach-resort            7     2023-07-06              7  ...
#
#    com_texto nao_vazio  traduzido  depois_2017  analisar  \
# 0       True      True      False         True      True
# 1       True      True      False         True      True
# 2       True      True      False         True      True
# 3       True      True      False         True      True
# 4       True      True      False         True      True
#
#    philschmid/distilbert-base-multilingual-cased-sentiment  \
# 0  {'label': 'positive', 'score': 0.9849022030830...
# 1  {'label': 'positive', 'score': 0.9701986312866...
# 2  {'label': 'positive', 'score': 0.9857670068740...
# 3  {'label': 'positive', 'score': 0.8551892638206...
# 4  {'label': 'positive', 'score': 0.8495931029319...
#
#    lxyuan/distilbert-base-multilingual-cased-sentiments-student  \
# 0  {'label': 'positive', 'score': 0.9592684507369...
# 1  {'label': 'negative', 'score': 0.6602097153663...
# 2  {'label': 'positive', 'score': 0.9891675710678...
# 3  {'label': 'positive', 'score': 0.781340479850769}
# 4  {'label': 'positive', 'score': 0.5628671050071...
#
#   citizenlab/twitter-xlm-roberta-base-sentiment-finetunned  \
# 0  {'label': 'Positive', 'score': 0.9925462603569...
# 1  {'label': 'Positive', 'score': 0.9922283291816...
# 2  {'label': 'Positive', 'score': 0.9923394918441...
# 3  {'label': 'Positive', 'score': 0.9930474162101...
# 4  {'label': 'Positive', 'score': 0.9923906922340...
#
#        cardiffnlp/twitter-xlm-roberta-base-sentiment  \
# 0  {'label': 'positive', 'score': 0.9392898678779...
# 1  {'label': 'positive', 'score': 0.8660374283790...
# 2  {'label': 'positive', 'score': 0.7664870023727...
# 3  {'label': 'positive', 'score': 0.9130381941795...
# 4  {'label': 'positive', 'score': 0.8959783315658...
#
#       ramonmedeiro1/bertimbau-products-reviews-pt-br
# 0  {'label': 'Muito Positivo', 'score': 0.9362657...
# 1  {'label': 'Muito Positivo', 'score': 0.8999789...
# 2  {'label': 'Muito Positivo', 'score': 0.9381666...
# 3  {'label': 'Muito Positivo', 'score': 0.9350948...
# 4  {'label': 'Positivo', 'score': 0.5224364995956...
#
# [5 rows x 22 columns]

# %%
cols = MODELS
teste['sentiment_bert'] = teste[cols].apply(lambda row: row.values.tolist(), axis=1)

# %%
import numpy as np

teste['sentiment_bert_max'] = teste['sentiment_bert'].apply(lambda x: MODELS[np.argmax(list(map(lambda y: y['score'], x)))])

# %%
teste[['sentiment_bert_max', 'sentiment_bert']].sample(n=10)
# Out:
#                                       sentiment_bert_max  \
# 36722  citizenlab/twitter-xlm-roberta-base-sentiment-...
# 33104  philschmid/distilbert-base-multilingual-cased-...
# 17964  citizenlab/twitter-xlm-roberta-base-sentiment-...
# 46450  philschmid/distilbert-base-multilingual-cased-...
# 32643  citizenlab/twitter-xlm-roberta-base-sentiment-...
# 20434  citizenlab/twitter-xlm-roberta-base-sentiment-...
# 30833  citizenlab/twitter-xlm-roberta-base-sentiment-...
# 18150  philschmid/distilbert-base-multilingual-cased-...
# 5988       cardiffnlp/twitter-xlm-roberta-base-sentiment
# 48853  citizenlab/twitter-xlm-roberta-base-sentiment-...
#
#                                           sentiment_bert
# 36722  [{'label': 'positive', 'score': 0.986613094806...
# 33104  [{'label': 'positive', 'score': 0.993849694728...
# 17964  [{'label': 'negative', 'score': 0.549580395221...
# 46450  [{'label': 'positive', 'score': 0.987415611743...
# 32643  [{'label': 'positive', 'score': 0.954417586326...
# 20434  [{'label': 'negative', 'score': 0.931371331214...
# 30833  [{'label': 'negative', 'score': 0.404063433408...
# 18150  [{'label': 'positive', 'score': 0.996461331844...
# 5988   [{'label': 'positive', 'score': 0.566017448902...
# 48853  [{'label': 'positive', 'score': 0.980140507221...

# %%
def f7(seq):
    seen = set()
    seen_add = seen.add
    return [x for x in seq if not (x in seen or seen_add(x))]
teste['sentiment_label'] = teste['sentiment_bert'].apply(lambda x: f7(list(map(lambda y: y['label'].lower(), x))))
teste['sentiment_score'] = teste['sentiment_bert'].apply(lambda x: set(map(lambda y: y['score'], x)))

# %%
teste[['ano_avaliacao', 'source', 'text', 'sentiment_bert', 'sentiment_label', 'sentiment_score']].sample(n = 30)
# Out:
#        ano_avaliacao                                        source  \
# 41306           2020                               iberostar-bahia
# 37610           2023                               iberostar-bahia
# 12364           2021                 la-torre-resort-all-inclusive
# 11692           2022                 la-torre-resort-all-inclusive
# 20957           2023          makai-resort-aracaju---all-inclusive
# 13875           2018                 la-torre-resort-all-inclusive
# 8133            2019            hotel-vila-galé_-eco-resort---cabo
# 4126            2022           salinas-maceió-all-inclusive-resort
# 2658            2022                      transamerica-comandatuba
# 34966           2020                         hotel-vila-galé-marés
# 47108           2021         salinas-maragogi-all-inclusive-resort
# 26062           2022               cana-brava-all-inclusive-resort
# 34889           2020                         hotel-vila-galé-marés
# 20882           2018                            grand-oca-maragogi
# 39692           2022                               iberostar-bahia
# 45962           2022         salinas-maragogi-all-inclusive-resort
# 35188           2020                         hotel-vila-galé-marés
# 28286           2022               cana-brava-all-inclusive-resort
# 11238           2018  nauticomar-resort-all-inclusive-_-beach-club
# 30963           2019               cana-brava-all-inclusive-resort
# 33084           2022                         hotel-vila-galé-marés
# 13205           2019                 la-torre-resort-all-inclusive
# 17              2023                     hotel-marsol-beach-resort
# 13231           2019                 la-torre-resort-all-inclusive
# 22384           2020          makai-resort-aracaju---all-inclusive
# 37584           2023                               iberostar-bahia
# 17857           2021                      hotel-vila-galé---touros
# 41302           2020                               iberostar-bahia
# 20601           2018                            grand-oca-maragogi
# 10793           2019  nauticomar-resort-all-inclusive-_-beach-club
#
#                                                     text  \
# 41306  Lugar maravilhoso, comida boa e atendimento di...
# 37610  eu agradeço a equipe de animação, todos são ex...
# 12364  Lugar maravilhoso, tudo perfeito alimentação e...
# 11692                                        Maravilhoso
# 20957  Quartos: Bem simples Facilidade de deslocament...
# 13875  As melhores férias da minha vida!!! É muito se...
# 8133                                     Hotel Vila Galé
# 4126   Decadente, estrutura antiga e nem a praia em f...
# 2658   Excelente resort. O que mais gostei? Do lugar,...
# 34966                 Top dos tops,, nível internacional
# 47108                        Mais do que bom.... Top !!!
# 26062  Comida boa, bebida gelada, atendimento bom e q...
# 34889                                        Sensacional
# 20882  Excelente local, limpeza e organização, praia ...
# 39692  Excelente hospedagem, ótimo lugar bem arejado ...
# 45962  Quartos: Bem organizado Atividades próximas: C...
# 35188  Espetacular. Acomodação, serviços, localização...
# 28286                          Excelente lugar descanso.
# 11238                        O quarto precisa de reforma
# 30963  O Resort é excelente, com muitas atividades pa...
# 33084  Estive nesse hotel em 2018 e retornei agora em...
# 13205  Atendimento excelente  . Fiz ótimas aulas de y...
# 17     Quadra, piscina, praça e ao lado da praia sem ...
# 13231                                  Melhor impossível
# 22384  Foi maravilhoso inesquecível recomendo vcs são...
# 37584  Comidas e bebidas: Ótima qualidade Destaques d...
# 17857  Hotel novo, quartos amplos e muito confortávei...
# 41302  Gostaria de agradecer imensamente a atenção da...
# 20601                                              Ótimo
# 10793       Ótimo atendimento falta uma pouco de reforma
#
#                                           sentiment_bert  \
# 41306  [{'label': 'Positive', 'score': 0.992427408695...
# 37610  [{'label': 'Positive', 'score': 0.987260103225...
# 12364  [{'label': 'Positive', 'score': 0.992297112941...
# 11692  [{'label': 'Positive', 'score': 0.992010235786...
# 20957  [{'label': 'Neutral', 'score': 0.9557094573974...
# 13875  [{'label': 'positive', 'score': 0.994778752326...
# 8133   [{'label': 'Neutral', 'score': 0.9828593134880...
# 4126   [{'label': 'Muito Negativo', 'score': 0.983589...
# 2658   [{'label': 'Positive', 'score': 0.988367855548...
# 34966  [{'label': 'Positive', 'score': 0.992025136947...
# 47108  [{'label': 'Positive', 'score': 0.992359817028...
# 26062  [{'label': 'Positive', 'score': 0.989228606224...
# 34889  [{'label': 'Positive', 'score': 0.989232540130...
# 20882  [{'label': 'Positive', 'score': 0.987138688564...
# 39692  [{'label': 'positive', 'score': 0.994002878665...
# 45962  [{'label': 'positive', 'score': 0.976078152656...
# 35188  [{'label': 'positive', 'score': 0.992693424224...
# 28286  [{'label': 'positive', 'score': 0.993389368057...
# 11238  [{'label': 'Neutral', 'score': 0.9526318311691...
# 30963  [{'label': 'negative', 'score': 0.943354785442...
# 33084  [{'label': 'Muito Negativo', 'score': 0.847010...
# 13205  [{'label': 'positive', 'score': 0.991347968578...
# 17     [{'label': 'Muito Positivo', 'score': 0.967500...
# 13231  [{'label': 'Positive', 'score': 0.952248334884...
# 22384  [{'label': 'Positive', 'score': 0.992124259471...
# 37584  [{'label': 'positive', 'score': 0.978617250919...
# 17857  [{'label': 'positive', 'score': 0.997207701206...
# 41302  [{'label': 'Positive', 'score': 0.991286575794...
# 20601  [{'label': 'Positive', 'score': 0.992536962032...
# 10793  [{'label': 'Positive', 'score': 0.986208200454...
#
#                                      sentiment_label  \
# 41306                     [positive, muito positivo]
# 37610                     [positive, muito positivo]
# 12364                     [positive, muito positivo]
# 11692                     [positive, muito positivo]
# 20957                  [neutral, positivo, positive]
# 13875                     [positive, muito positivo]
# 8133   [neutral, negative, positive, muito positivo]
# 4126            [muito negativo, negative, positive]
# 2658                      [positive, muito positivo]
# 34966                     [positive, muito positivo]
# 47108                     [positive, muito positivo]
# 26062                     [positive, muito positivo]
# 34889                     [positive, muito positivo]
# 20882                     [positive, muito positivo]
# 39692                     [positive, muito positivo]
# 45962            [positive, muito positivo, neutral]
# 35188                     [positive, muito positivo]
# 28286                     [positive, muito positivo]
# 11238        [neutral, negativo, negative, positive]
# 30963                    [negative, neutral, neutro]
# 33084            [muito negativo, negative, neutral]
# 13205                     [positive, muito positivo]
# 17               [muito positivo, neutral, positive]
# 13231                     [positive, muito positivo]
# 22384                     [positive, muito positivo]
# 37584                     [positive, muito positivo]
# 17857                     [positive, muito positivo]
# 41302                     [positive, muito positivo]
# 20601                     [positive, muito positivo]
# 10793        [positive, positivo, negative, neutral]
#
#                                          sentiment_score
# 41306  {0.992427408695221, 0.986170768737793, 0.92036...
# 37610  {0.987260103225708, 0.9837772846221924, 0.9076...
# 12364  {0.9922971129417419, 0.9190921187400818, 0.613...
# 11692  {0.992010235786438, 0.9772497415542603, 0.7661...
# 20957  {0.9557094573974609, 0.5531846880912781, 0.475...
# 13875  {0.9947787523269653, 0.9918925762176514, 0.933...
# 8133   {0.9828593134880066, 0.7894825339317322, 0.488...
# 4126   {0.9835894107818604, 0.9163910746574402, 0.496...
# 2658   {0.9883678555488586, 0.9748656749725342, 0.761...
# 34966  {0.9920251369476318, 0.9910534024238586, 0.852...
# 47108  {0.9923598170280457, 0.9442901611328125, 0.623...
# 26062  {0.9892286062240601, 0.9702566266059875, 0.896...
# 34889  {0.9892325401306152, 0.9831801652908325, 0.679...
# 20882  {0.9871386885643005, 0.9833712577819824, 0.909...
# 39692  {0.9940028786659241, 0.98867267370224, 0.82163...
# 45962  {0.9760781526565552, 0.9471296668052673, 0.775...
# 35188  {0.9926934242248535, 0.9920193552970886, 0.919...
# 28286  {0.993389368057251, 0.9896112680435181, 0.8862...
# 11238  {0.9526318311691284, 0.7686407566070557, 0.422...
# 30963  {0.9433547854423523, 0.9028695821762085, 0.417...
# 33084  {0.8470105528831482, 0.7394356727600098, 0.400...
# 13205  {0.9913479685783386, 0.9900667667388916, 0.913...
# 17     {0.9675008654594421, 0.6083300113677979, 0.481...
# 13231  {0.9522483348846436, 0.8054404854774475, 0.614...
# 22384  {0.9921242594718933, 0.9784790873527527, 0.573...
# 37584  {0.978617250919342, 0.9590063691139221, 0.7964...
# 17857  {0.9972077012062073, 0.989243745803833, 0.9430...
# 41302  {0.99128657579422, 0.9880359768867493, 0.91123...
# 20601  {0.9925369620323181, 0.8494864106178284, 0.515...
# 10793  {0.9862082004547119, 0.6859799027442932, 0.437...

# %%
teste[teste.text == 'Lindo d mais']
# Out:
#                   retrieval_date  rating relative_date  likes  \
# 5962  2023-07-07 00:59:10.935631     3.0  5 anos atrás      0
#
#      user_is_local_guide          text                               source  \
# 5962                True  Lindo d mais  salinas-maceió-all-inclusive-resort
#
#      user_reviews data_avaliacao  mes_avaliacao  ...  depois_2017 analisar  \
# 5962           13     2018-07-08              7  ...         True     True
#
#                                        sentiment_bert_1  \
# 5962  {'label': 'neutral', 'score': 0.4194217622280121}
#
#                                        sentiment_bert_2  \
# 5962  {'label': 'positive', 'score': 0.5910865664482...
#
#                                        sentiment_bert_3  \
# 5962  {'label': 'Positive', 'score': 0.9915336966514...
#
#                                        sentiment_bert_4  \
# 5962  {'label': 'positive', 'score': 0.8819499015808...
#
#                                        sentiment_bert_5  \
# 5962  {'label': 'Muito Positivo', 'score': 0.9520753...
#
#                                          sentiment_bert  \
# 5962  [{'label': 'Positive', 'score': 0.991533696651...
#
#                           sentiment_label  \
# 5962  [positive, muito positivo, neutral]
#
#                                         sentiment_score
# 5962  {0.9915336966514587, 0.9520753026008606, 0.419...
#
# [1 rows x 25 columns]

# %%
teste.to_csv('/content/gdrive/MyDrive/tcc/bert/analise_sentimento_v3.csv')

# %% [markdown]
# # bert
#
# https://medium.com/data-hackers/an%C3%A1lise-de-sentimentos-em-portugu%C3%AAs-utilizando-pytorch-e-python-91a232165ec0
#
# https://sol.sbc.org.br/index.php/stil/article/view/17784
#
# https://towardsdatascience.com/sentiment-analysis-in-10-minutes-with-bert-and-hugging-face-294e8a04b671

# %%
teste['sentiment_label'][0]
# Out:
# "['positive']"
